# %%
import pandas as pd

# %%
#Mounting drive to access dataset stored at google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Preprocessing

# %%
#Making dataframe from csv dataset
df = pd.read_csv('/content/drive/MyDrive/CODSOFT INTERNSHIP/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#Null values in each column
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#NaN values in each column
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#Unique values in Class column
df['Class'].unique()
# Out:
# array([0, 1])

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
#Entries in each class in Class column
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# this dataset is highly imbalanced

# %%
#Classify dataframe into legit and fraudulent entries
legit = df[df['Class']==0]
fraud = df[df['Class']==1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# there is significant difference in legit and fraud amount mean

# %%
# Construct a sample dataframe from legit dataframe with size of fraud dataset
legit_sample = legit.sample(n = len(fraud))

# %%
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 126055   77913.0  0.629466 -0.739025 -0.049696  1.045251 -0.368887  0.659931
# 210324  137927.0 -0.401454  0.148059  0.590621 -2.134922  0.324195 -0.378484
# 187700  127650.0 -1.472823  0.921163  0.123071 -0.127100  0.824936 -0.353902
# 230776  146476.0  0.045750  1.517366  0.667313  2.761372  1.046584 -0.395597
# 191256  129180.0  1.890232  0.236375 -0.167256  4.069593 -0.152955  0.138700
# ...          ...       ...       ...       ...       ...       ...       ...
# 236936  149027.0 -0.916128 -0.589108  0.706439 -1.060975  1.199196  1.851835
# 96200    65657.0 -1.167137 -0.508876  2.725736 -0.969228  0.047246  0.141764
# 217602  140957.0 -4.719408 -2.818399 -2.185746 -0.566737 -0.828111  0.243388
# 142110   84580.0  1.246445 -0.423837  0.886913 -0.716191 -1.300229 -0.846907
# 204899  135494.0 -0.464197  1.408062 -1.681679 -0.171607 -0.168682 -0.770478
#
# ...

# %%
# Construct a new dataframe with concatenation of new sample dataframe and fraud fataframe
new_data = pd.concat([legit_sample,fraud], axis = 0)

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 126055   77913.0  0.629466 -0.739025 -0.049696  1.045251 -0.368887  0.659931
# 210324  137927.0 -0.401454  0.148059  0.590621 -2.134922  0.324195 -0.378484
# 187700  127650.0 -1.472823  0.921163  0.123071 -0.127100  0.824936 -0.353902
# 230776  146476.0  0.045750  1.517366  0.667313  2.761372  1.046584 -0.395597
# 191256  129180.0  1.890232  0.236375 -0.167256  4.069593 -0.152955  0.138700
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 126055 -0.242769  0.351271  0.593169  ...  0.139104  0.215042 -0.296986
# 210324  0.068188  0.083603 -0.779905  ...  0.294149  0.735186 -0.266834
# 187700  1.680418  0.271936 -1.322723  ...  0.217347  0.212036 -0.332860
# 230776  1.216516 -0.190389 -1.931133  ...  0.312069  0.871280 -0.216316
# 191256 -0.262764  0.088766 -0.046135  ...  0.068036  0.427510  0.098276
#
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95803.117886 -0.067328  0.076525  0.027954  0.015646 -0.018090
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.045327  0.055009 -0.064008 -0.017461  ... -0.014881 -0.056517
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.042140 -0.052172 -0.017366 -0.021761 -0.033930  0.002373 -0.002324
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       94.346667
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# This change in mean value is not much. That's mean the dataset is good in nature.

# %% [markdown]
# # Machine Learning

# %%
### Split Dataset into Features and Target
X = new_data.drop(columns = 'Class',axis = 1)
Y = new_data['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 126055   77913.0  0.629466 -0.739025 -0.049696  1.045251 -0.368887  0.659931
# 210324  137927.0 -0.401454  0.148059  0.590621 -2.134922  0.324195 -0.378484
# 187700  127650.0 -1.472823  0.921163  0.123071 -0.127100  0.824936 -0.353902
# 230776  146476.0  0.045750  1.517366  0.667313  2.761372  1.046584 -0.395597
# 191256  129180.0  1.890232  0.236375 -0.167256  4.069593 -0.152955  0.138700
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 126055    0
# 210324    0
# 187700    0
# 230776    0
# 191256    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
# importing libraries and frameworks for data training
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Split the data into training and testing
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2,stratify = Y, random_state=42)

# %%
print(X.shape,X_train.shape,X_test.shape,Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30) (984,) (787,) (197,)

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Logistic Regression

# %%
model = LogisticRegression().fit(X_train,Y_train)

# %%
model
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy score

# %%
#accuracy on train data
X_train_prediction = model.predict(X_train)
accuracy_training = accuracy_score(X_train_prediction,Y_train)

# %%
accuracy_training
# Out:
# 0.9034307496823379

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
accuracy_testing = accuracy_score(X_test_prediction,Y_test)
accuracy_testing
# Out:
# 0.9543147208121827
